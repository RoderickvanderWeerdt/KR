# %% [markdown]
# based on original code from "CSV2RDF-tutorial.ipynb".
#
# Changed made by Roderick van der Weerdt & Nienke Speet.

# %% [markdown]
# # Handling the Data:

# %%
# Converts csv into dict.
from csv import DictReader

filename = "EtenDrinken_clean.csv"

with open(filename,'r') as csvfile:
    csv_contents = [{k: v for k, v in row.items()}
        for row in DictReader(csvfile, skipinitialspace=True, quotechar='"', delimiter=';')]
    
filename = "OVHALTES.csv"
    
with open(filename,'r') as stopfile:
    stop_contents = [{k: v for k, v in row.items()}
        for row in DictReader(stopfile, skipinitialspace=True, quotechar='"', delimiter=';')]

# %%
# Returns a dict where the key is the route identifier which holds all the 
# destinations of the route. Destinations are only added when they have 
# not been added allready (uses similarity.py to determine whether the
# destination was allready added).

from similarity import similarity

def checkDest(dest_dict, line_id, dest):
    if dest not in dest_dict[line_id]:
        new = True
        for other_dest in dest_dict[line_id]:
            if similarity(other_dest, dest) > 0.6:
                if len(other_dest) < len(dest):
                    dest_dict[line_id].remove(other_dest)
                    dest_dict[line_id].append(dest)
                new = False
        if new:
            dest_dict[line_id].append(dest)
            
def testInt(s):
    try: 
        int(s)
        return True
    except ValueError:
        return False

dicto = dict()

for row in stop_contents:
    lines = row['Lijnen_en_bestemming'].split(',')
#     print lines
    for line in lines:
        if line == '':
            continue
        line_split = line.split(' ')
        while '' in line_split:
            line_split.remove('')
        line_id = line_split[0]
        if len(line_id) > 3:
            continue
        destination = ""
        for word in line_split[1:]:
            destination += word + ' '
        destination = destination[:-1]
        if dicto.has_key(line_split[0]):
            checkDest(dicto, line_id, destination)
        else:
            dicto[line_id] = [destination]

route_dict = dicto

# %% [markdown]
# ### Setting up stuff for RDF
#
# We import the things we'll need from `rdflib`:
#
# * `Dataset` is the object in which we will store our RDF graphs
# * `URIRef` is the datatype for URI-resources
# * `Literal` is the datatype for literal resources (strings, dates etc.)
# * `Namespace` is used to create namespaces (parts of the URI's we are going to make)
# * `RDF`, `RDFS`, `OWL` and `XSD` are built in namespaces
#
# **NB**: We'll use "group 2", which is our groupname.

# %%
from rdflib import Dataset, URIRef, Literal, Namespace, RDF, RDFS, OWL, XSD

# A namespace for our resources
data = 'http://data.krw.d2s.labs.vu.nl/group2/resource/'
DATA = Namespace(data)
# A namespace for our vocabulary items (schema information, RDFS, OWL classes and properties etc.)
vocab = 'http://data.krw.d2s.labs.vu.nl/group2/resource/'
VOCAB = Namespace('http://data.krw.d2s.labs.vu.nl/group2/resource/')

GEO = Namespace('http://www.w3.org/2003/01/geo/wgs84_pos#')
DB_OWL = Namespace('http://dbpedia.org/ontology/')
SCHEMA = Namespace('http://schema.org/')
SWPO = Namespace('http://sw-portal.deri.org/ontologies/swportal#')
PLACE = Namespace('http://purl.org/ontology/places#')

# The URI for our graph
graph_uri = URIRef('http://data.krw.d2s.labs.vu.nl/resource/graph2')

# We initialize a dataset, and bind our namespaces
dataset = Dataset()
dataset.bind('g2data',DATA)
dataset.bind('g2vocab',VOCAB)

dataset.bind('geo',GEO)
dataset.bind('dbpedia-owl', DB_OWL)
dataset.bind('schema', SCHEMA)
dataset.bind('swpo', SWPO)
dataset.bind('place', PLACE)

# We then get a new graph object with our URI from the dataset.
graph = dataset.graph(graph_uri)

# %% [markdown]
# ### Let's make some RDF from our CSV Dictionary
#
# A straightforward conversion:
#
# * Make sure you have URIRef objects for all resources you want to make
# * Make sure you have Literal objects for all literal values you need. Be sure to use the proper datatype or a language tag.
# * Decide on what URI will be the 'primary key' for each row.
# * Decide on the terms you are going to use to create the relations (predicates, properties)
# * Add the triples to the graph

# %%
#Make a graph from the venue data

# IRI baker is a library that reliably creates valid (parts of) IRIs from strings (spaces are turned into underscores, etc.).
from iribaker import to_iri

for row in csv_contents:
    toko = URIRef(to_iri(data + row['Title'] + '_' + row['Zipcode']))
    toko_name = Literal(row['Title'], datatype=XSD['string'])
    toko_type = URIRef(to_iri(VOCAB['Toko']))
    
    city = URIRef(to_iri(data + row['City']))
    city_type = URIRef(to_iri(DB_OWL['city']))
    city_name = Literal(row['City'], lang='nl')
    
    urls = row['Urls'].split(',')
    for url in urls:
        if len(url) > 0:
            url = Literal(url, datatype=XSD['string'])
            graph.add((toko, SCHEMA['url'], url))
    
    # Media are url-links to pictures of the venue
    medias = row['Media'].split(',')
    for media in medias:
        if len(media) > 0:
            media = Literal(media, datatype=XSD['string'])
            graph.add((toko, DB_OWL['Media'], media))
    
    calendar = row['Calendarsummary']
    if len(calendar) > 0:
        calendar = Literal(calendar, datatype=XSD['string'])
        graph.add((toko, VOCAB['opening_hours'], calendar))
        
    address = row['Adres']
    if len(address) > 0:
        address = Literal(address, datatype=XSD['string'])
        graph.add((toko, SWPO['hasAddress'], address))
        
    zipcode = row['Zipcode']
    if len(zipcode) > 0:
        zipcode = Literal(zipcode, datatype=XSD['string'])
        graph.add((toko, SWPO['hasZipCode'], zipcode))
    
    #change dutch decimal mark (',') to international ('.')
    lat = row['Latitude'].replace(',', '.')
    lon = row['Longitude'].replace(',', '.')
    
    latitude = Literal(float(lat), datatype=XSD['double'])
    longitude = Literal(float(lon), datatype=XSD['double'])
    
    use_lat = Literal(lat[:lat.find('.')+3], datatype=XSD['string'])
    use_long = Literal(lon[:lon.find('.')+3], datatype=XSD['string'])
    
    # All set... we are now going to add the triples to our graph
    graph.add((toko, RDF.type, toko_type))
    graph.add((toko, RDFS.label, toko_name))
    graph.add((toko, PLACE['in'], city))
    graph.add((toko, GEO['lat'], latitude))
    graph.add((toko, GEO['long'], longitude))
    
    graph.add((toko, VOCAB['use_lat'], use_lat))
    graph.add((toko, VOCAB['use_long'], use_long))
    
    graph.add((city, RDF.type, city_type))
    graph.add((city, RDFS.label, city_name))

# %%
# Make a graph from the stop data.

def getRouteIDs(routes):
    route_ids = []
    routes = routes.split(',')
    for route in routes:
        if route == '':
            continue
        route_split = route.split(' ')
        while '' in route_split:
            route_split.remove('')
        route_id = route_split[0]
        if len(route_id) > 3:
            continue
        else:
            route_ids.append(route_id)

    return list(set(route_ids))

for row in stop_contents: 
    stop = URIRef(to_iri(data + 'Stop' + row['\xef\xbb\xbfOBJECTNUMMER']))
    stop_id = Literal(row['\xef\xbb\xbfOBJECTNUMMER'], datatype=XSD['int'])
    
    stop_type = URIRef(to_iri(VOCAB['Stop']))
    
    route_ids = getRouteIDs(row['Lijnen_en_bestemming'])
    
    for route_id in route_ids:
        route = URIRef(to_iri(data + "ROUTE_" + route_id))
        graph.add((route, RDF.type, URIRef(to_iri(VOCAB['Route']))))
        graph.add((stop, VOCAB['Routes'], route))
        for dest in route_dict[route_id]:
            destination = Literal(dest, datatype=XSD['string'])
            graph.add((route, VOCAB['Destination'], destination))
    
    #change dutch decimal mark (',') to international ('.')
    lat = row['LAT'].replace(',', '.')
    lon = row['LNG'].replace(',', '.')
    
    latitude = Literal(float(lat), datatype=XSD['double'])
    longitude = Literal(float(lon), datatype=XSD['double'])
    
    use_lat = Literal(lat[:lat.find('.')+3], datatype=XSD['string'])
    use_long = Literal(lon[:lon.find('.')+3], datatype=XSD['string'])
    
    graph.add((stop, RDF.type, stop_type))
    graph.add((stop, RDFS.label, stop_id))
    graph.add((stop, GEO['lat'], latitude))
    graph.add((stop, GEO['long'], longitude))
    graph.add((stop, VOCAB['use_lat'], use_lat))
    graph.add((stop, VOCAB['use_long'], use_long))

# %% [markdown]
# Let's see how this turned out:

# %%
print dataset.serialize(format='trig')
# Out:
# @prefix dbpedia-owl: <http://dbpedia.org/ontology/> .
# @prefix g2data: <http://data.krw.d2s.labs.vu.nl/group2/resource/> .
# @prefix g2vocab: <http://data.krw.d2s.labs.vu.nl/group2/resource/> .
# @prefix geo: <http://www.w3.org/2003/01/geo/wgs84_pos#> .
# @prefix place: <http://purl.org/ontology/places#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <http://schema.org/> .
# @prefix swpo: <http://sw-portal.deri.org/ontologies/swportal#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <ns1:default> = {}
#
# <ns2:graph2> = {
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/'t_Beemster_Spijshuis_1462_HJ> a g2vocab:Toko ;
#         rdfs:label "'t Beemster Spijshuis"^^xsd:string ;
#         g2vocab:opening_hours "Ma: gesloten di-vr: 17:00 - 22:00 uur za, zo: 12:00 - 22:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.54"^^xsd:string ;
#         g2vocab:use_long "4.91"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20110217/26c350a7-f870-4acd-8936-6690cb4628e0.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110217/58be3797-3015-4239-9f50-964494f0a920.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110217/b5c19940-d842-4d15-93ea-5ccf3494933b.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110217/d62c4e28-4e39-42fc-bc6a-241de63e4557.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110217/e6d36e19-ba1f-4c11-996f-f2483b7f0f96.jpg"^^xsd:string ;
#         place:in g2vocab:MIDDENBEEMSTER ;
#         schema:url "http://www.beemsterspijshuis.nl"^^xsd:string ;
#         swpo:hasAddress "Middenweg 177"^^xsd:string ;
#         swpo:hasZipCode "1462 HJ"^^xsd:string ;
#         geo:lat 5.254815e+01 ;
#         geo:long 4.912455e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/'t_Heerenhuis_1458_PM> a g2vocab:Toko ;
#         rdfs:label "'t Heerenhuis"^^xsd:string ;
#         g2vocab:use_lat "52.53"^^xsd:string ;
#         g2vocab:use_long "4.81"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20110217/62b1db20-e99e-432a-8063-33d08ff9e065.jpg"^^xsd:string ;
#         place:in g2vocab:SPIJKERBOOR_NH ;
#         schema:url "http://www.heerenhuis.com/"^^xsd:string ;
#         swpo:hasAddress "Starnmeerdijk 21"^^xsd:string ;
#         swpo:hasZipCode "1458 PM"^^xsd:string ;
#         geo:lat 5.253076e+01 ;
#         geo:long 4.812779e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/'t_Kalfje_1015_DA> a g2vocab:Toko ;
#         rdfs:label "'t Kalfje"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.eetcafehetkalfje.nl/"^^xsd:string ;
#         swpo:hasAddress "Prinsenstraat 5"^^xsd:string ;
#         swpo:hasZipCode "1015 DA"^^xsd:string ;
#         geo:lat 5.237772e+01 ;
#         geo:long 4.887017e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/63graden_Foodbar_1058_TB> a g2vocab:Toko ;
#         rdfs:label "63graden Foodbar"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.84"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/8a/8a2eb51f-23b2-40d6-86bb-a0b1b82f67a5/1f5c1b22-2155-4231-a625-a76865c77c8b.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/8a/8a2eb51f-23b2-40d6-86bb-a0b1b82f67a5/bbcd9dad-06c1-4946-888a-0593a8d4e65d.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.63graden.nl"^^xsd:string ;
#         swpo:hasAddress "Woestduinstraat 63"^^xsd:string ;
#         swpo:hasZipCode "1058 TB"^^xsd:string ;
#         geo:lat 5.235276e+01 ;
#         geo:long 4.847989e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/@7_1078_GN> a g2vocab:Toko ;
#         rdfs:label "@7"^^xsd:string ;
#         g2vocab:opening_hours "Ma-vr: 07:00 - 17:00 uur za: 08:00 - 17:00 uur zo: 09:00 - 17:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.34"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20150323/9a24c8c0-1295-4b04-9211-39b6e012cd08.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20150323/ba15df05-de81-44c8-ad5f-1f8bdd586b10.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.at7online.nl/"^^xsd:string ;
#         swpo:hasAddress "Scheldestraat 92"^^xsd:string ;
#         swpo:hasZipCode "1078 GN"^^xsd:string ;
#         geo:lat 5.234561e+01 ;
#         geo:long 4.890664e+00 .
#
#     g2vocab:A_La_Ferme_1073_BX a g2vocab:Toko ;
#         rdfs:label "A La Ferme"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.alaferme.nl"^^xsd:string ;
#         swpo:hasAddress "Govert Flinckstraat 251"^^xsd:string ;
#         swpo:hasZipCode "1073 BX"^^xsd:string ;
#         geo:lat 5.235635e+01 ;
#         geo:long 4.898114e+00 .
#
#     g2vocab:A_Tavola_1018_AC a g2vocab:Toko ;
#         rdfs:label "A Tavola"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.91"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120521/aaf5146a-908a-4b68-afc1-001139c1f7f0.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.atavolarestaurant.nl"^^xsd:string ;
#         swpo:hasAddress "Kadijksplein 9"^^xsd:string ;
#         swpo:hasZipCode "1018 AC"^^xsd:string ;
#         geo:lat 5.237022e+01 ;
#         geo:long 4.912259e+00 .
#
#     g2vocab:A_la_Ferme_1073_BX a g2vocab:Toko ;
#         rdfs:label "A la Ferme"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.alaferme.nl"^^xsd:string ;
#         swpo:hasAddress "Govert Flinckstraat 251"^^xsd:string ;
#         swpo:hasZipCode "1073 BX"^^xsd:string ;
#         geo:lat 5.235635e+01 ;
#         geo:long 4.898114e+00 .
#
#     g2vocab:Aan_de_Amstel_1091_EE a g2vocab:Toko ;
#         rdfs:label "Aan de Amstel"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.90"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/39/3992ceb0-4262-4f51-8fee-af0b1e621704/5e449e5c-2074-4d00-abf6-fd8ad251e0a0.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/39/3992ceb0-4262-4f51-8fee-af0b1e621704/f116ac87-5b35-4bd1-bcca-e796b1fb7354.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.aan-de-amstel.nl"^^xsd:string ;
#         swpo:hasAddress "Weesperzijde 42a"^^xsd:string ;
#         swpo:hasZipCode "1091 EE"^^xsd:string ;
#         geo:lat 5.23558e+01 ;
#         geo:long 4.907445e+00 .
#
#     g2vocab:Aan_de_Poel_1185_TS a g2vocab:Toko ;
#         rdfs:label "Aan de Poel"^^xsd:string ;
#         g2vocab:opening_hours "ma: gesloten di-vr: 12:00 - 14:30 en 18:00 - 22:00 uur za: 18:00 - 22:00 uur zo: gesloten"^^xsd:string ;
#         g2vocab:use_lat "52.29"^^xsd:string ;
#         g2vocab:use_long "4.84"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120913/ee96f608-4ebb-4a7b-8830-ba9c3ef7d01e.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTELVEEN ;
#         schema:url "http://www.restaurantaandepoel.nl/"^^xsd:string ;
#         swpo:hasAddress "Handweg 1"^^xsd:string ;
#         swpo:hasZipCode "1185 TS"^^xsd:string ;
#         geo:lat 5.229584e+01 ;
#         geo:long 4.844655e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Adam_&_Siam_1012_KM> a g2vocab:Toko ;
#         rdfs:label "Adam & Siam"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/dc/dc7284af-66aa-43c3-825f-91656cba490c/b54aaf21-7f40-4001-b03e-d4fba4e9e281.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/dc/dc7284af-66aa-43c3-825f-91656cba490c/ba1184bc-c48c-4d01-a876-01f78805232d.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/dc/dc7284af-66aa-43c3-825f-91656cba490c/d9229d74-ff80-4ad8-b820-0403728661e6.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.adamsiam.nl/"^^xsd:string ;
#         swpo:hasAddress "Rokin 93"^^xsd:string ;
#         swpo:hasZipCode "1012 KM"^^xsd:string ;
#         geo:lat 5.237007e+01 ;
#         geo:long 4.892992e+00 .
#
#     g2vocab:Affourtit_1075_CS a g2vocab:Toko ;
#         rdfs:label "Affourtit"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.85"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.affourtit.nl"^^xsd:string ;
#         swpo:hasAddress "Koninginneweg 209"^^xsd:string ;
#         swpo:hasZipCode "1075 CS"^^xsd:string ;
#         geo:lat 5.23522e+01 ;
#         geo:long 4.859774e+00 .
#
#     g2vocab:Afrikaans_Restaurant_Kilimanjaro_1011_VB a g2vocab:Toko ;
#         rdfs:label "Afrikaans Restaurant Kilimanjaro"^^xsd:string ;
#         g2vocab:opening_hours "ma: gesloten di-vr: 16:00 - 00:00 uur za: gesloten zo: 16:00 - 00:00 uur"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.91"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         swpo:hasAddress "Rapenburgerplein 6 HS"^^xsd:string ;
#         swpo:hasZipCode "1011 VB"^^xsd:string ;
#         geo:lat 5.237032e+01 ;
#         geo:long 4.910838e+00 .
#
#     g2vocab:Ajuma_2042_AG a g2vocab:Toko ;
#         rdfs:label "Ajuma"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.52"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/eb/ebaf1f02-1d9d-4673-b17b-d31909b4e1c4/14d1c35d-b2e9-4ec5-bf42-2a58e5476042.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/eb/ebaf1f02-1d9d-4673-b17b-d31909b4e1c4/18b04942-f31b-4748-915f-328f2e100edb.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/eb/ebaf1f02-1d9d-4673-b17b-d31909b4e1c4/aa89e692-86d9-4494-ac3b-eb9435dc2295.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/eb/ebaf1f02-1d9d-4673-b17b-d31909b4e1c4/bf04c6b6-310e-42a4-ba71-c1bc3384efb6.jpg"^^xsd:string ;
#         place:in g2vocab:ZANDVOORT ;
#         schema:url "http://ajuma.nl/"^^xsd:string ;
#         swpo:hasAddress "Zuidstrand  2"^^xsd:string ;
#         swpo:hasZipCode "2042 AG"^^xsd:string ;
#         geo:lat 5.23702e+01 ;
#         geo:long 4.523311e+00 .
#
#     g2vocab:Akbar_Indian_Restaurant_1017_PV a g2vocab:Toko ;
#         rdfs:label "Akbar Indian Restaurant"^^xsd:string ;
#         g2vocab:opening_hours "ma-zo: 16:30 - 00:30 uur"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.akbar.nl"^^xsd:string ;
#         swpo:hasAddress "Korte Leidsedwarsstraat 15"^^xsd:string ;
#         swpo:hasZipCode "1017 PV"^^xsd:string ;
#         geo:lat 5.236529e+01 ;
#         geo:long 4.881914e+00 .
#
#     g2vocab:Akitsu_1016_SZ a g2vocab:Toko ;
#         rdfs:label "Akitsu"^^xsd:string ;
#         g2vocab:opening_hours "Di-zo: 18:00 - 00:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.87"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         swpo:hasAddress "Rozengracht 230"^^xsd:string ;
#         swpo:hasZipCode "1016 SZ"^^xsd:string ;
#         geo:lat 5.237211e+01 ;
#         geo:long 4.87526e+00 .
#
#     g2vocab:Al_Argentino_Restaurant_Steakhouse_1012_AP a g2vocab:Toko ;
#         rdfs:label "Al Argentino Restaurant Steakhouse"^^xsd:string ;
#         g2vocab:opening_hours "ma-zo: 12:00 - 23:00 uur"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.90"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20110124/14b31123-5872-43f9-a359-11c0d4a52628.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110124/93bccc93-a874-4976-8a3b-b111c51ee45a.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110124/cda4a374-62a9-4e39-9674-00b29f45e053.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.alargentino.nl"^^xsd:string,
#             "http://www.facebook.com/pages/Steakhouse-Al-Argentino/231209723571733?fref=ts"^^xsd:string ;
#         swpo:hasAddress "Zeedijk 29A"^^xsd:string ;
#         swpo:hasZipCode "1012 AP"^^xsd:string ;
#         geo:lat 5.23757e+01 ;
#         geo:long 4.900975e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Alfonso's_Mexican_Restaurant_1017_VN> a g2vocab:Toko ;
#         rdfs:label "Alfonso's Mexican Restaurant"^^xsd:string ;
#         g2vocab:opening_hours "ma-zo: 17:00 - 23:00 uur"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20110124/d1231e16-bfb6-4120-8f42-c721b50a55dd.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110124/e888e5d3-c02b-4966-bf0e-64c1510391b9.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.alfonsosrestaurant.com"^^xsd:string ;
#         swpo:hasAddress "Utrechtsestraat 32"^^xsd:string ;
#         swpo:hasZipCode "1017 VN"^^xsd:string ;
#         geo:lat 5.236442e+01 ;
#         geo:long 4.897942e+00 .
#
#     g2vocab:Aloha_Beach_1951_LA a g2vocab:Toko ;
#         rdfs:label "Aloha Beach"^^xsd:string ;
#         g2vocab:opening_hours "Ma-zo: 10:00 - 22:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.46"^^xsd:string ;
#         g2vocab:use_long "4.57"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/12/12669e4a-d661-4ed2-ae25-2a1de95b28cc/662edf61-12e7-4605-82ee-b9f75a68ddbe.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/12/12669e4a-d661-4ed2-ae25-2a1de95b28cc/aaafe2b5-49e6-4a5b-8fd2-0e83319ef539.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/12/12669e4a-d661-4ed2-ae25-2a1de95b28cc/d3be435b-3393-41d2-9557-bb549d6d2fb9.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/12/12669e4a-d661-4ed2-ae25-2a1de95b28cc/e44f0764-490a-45eb-9810-f4f8c0d29622.jpg"^^xsd:string ;
#         place:in g2vocab:VELSEN-NOORD ;
#         schema:url "http://alohabeach.nl/"^^xsd:string ;
#         swpo:hasAddress "Reyndersweg 2"^^xsd:string ;
#         swpo:hasZipCode "1951 LA"^^xsd:string ;
#         geo:lat 5.246903e+01 ;
#         geo:long 4.57205e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Amstel_Bar_&_Brasserie_1018_GX> a g2vocab:Toko ;
#         rdfs:label "Amstel Bar & Brasserie"^^xsd:string ;
#         g2vocab:opening_hours "ma-zo: 12:00 - 01:00 uur"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.90"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20110125/e01c5518-4708-447f-9a95-0c78ed847709.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.amsterdam.intercontinental.com"^^xsd:string ;
#         swpo:hasAddress "Professor Tulpplein 1"^^xsd:string ;
#         swpo:hasZipCode "1018 GX"^^xsd:string ;
#         geo:lat 5.236004e+01 ;
#         geo:long 4.905497e+00 .
#
#     g2vocab:Amstelhaven_1091_EW a g2vocab:Toko ;
#         rdfs:label "Amstelhaven"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.90"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.amstelhaven.nl"^^xsd:string ;
#         swpo:hasAddress "Mauritskade 1"^^xsd:string ;
#         swpo:hasZipCode "1091 EW"^^xsd:string ;
#         geo:lat 5.235976e+01 ;
#         geo:long 4.907344e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Anne&Max_1072_VE> a g2vocab:Toko ;
#         rdfs:label "Anne&Max"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20150326/7a000e3e-6348-4818-aa66-fa3905d4325b.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20150326/c860ea0c-7e4f-4b03-a1bc-b1f8757c8fd8.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.annemax.nl/"^^xsd:string ;
#         swpo:hasAddress "Gerard Douplein 10"^^xsd:string ;
#         swpo:hasZipCode "1072 VE"^^xsd:string ;
#         geo:lat 5.235585e+01 ;
#         geo:long 4.892741e+00 .
#
#     g2vocab:Apollo_Hotel_Lelystad_8224_BZ a g2vocab:Toko ;
#         rdfs:label "Apollo Hotel Lelystad"^^xsd:string ;
#         g2vocab:use_lat "52.51"^^xsd:string ;
#         g2vocab:use_long "5.47"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20110216/2b331424-5447-4a8e-91dd-ba56f70a8766.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110216/ad44c783-01e2-493e-9f07-9ff89889b69b.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110216/c417c7dd-b097-46c0-8383-1cff2b2b99c2.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110216/db44e797-1f6a-406d-b371-2939ecaf95d1.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110216/e6f1061f-2a22-4231-baa3-3b84198253bd.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110216/e9c08e74-bde0-463c-affc-7f3e96c15ae2.jpg"^^xsd:string ;
#         place:in g2vocab:LELYSTAD ;
#         schema:url "http://www.hotellelystad.nl"^^xsd:string ;
#         swpo:hasAddress "Agoraweg 11"^^xsd:string ;
#         swpo:hasZipCode "8224 BZ"^^xsd:string ;
#         geo:lat 5.251056e+01 ;
#         geo:long 5.4774e+00 .
#
#     g2vocab:Arc_-_tijdelijk_gesloten_1017_BM a g2vocab:Toko ;
#         rdfs:label "Arc - tijdelijk gesloten"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120521/033af708-d81e-4aac-bbde-d1073a616dd1.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         swpo:hasAddress "Reguliersdwarsstraat"^^xsd:string ;
#         swpo:hasZipCode "1017 BM"^^xsd:string ;
#         geo:lat 5.236619e+01 ;
#         geo:long 4.892187e+00 .
#
#     g2vocab:As_1077_WT a g2vocab:Toko ;
#         rdfs:label "As"^^xsd:string ;
#         g2vocab:use_lat "52.34"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120521/105848de-0629-47ca-8979-6ff7586315df.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.restaurantas.nl"^^xsd:string ;
#         swpo:hasAddress "Prinses Irenestraat 19"^^xsd:string ;
#         swpo:hasZipCode "1077 WT"^^xsd:string ;
#         geo:lat 5.234179e+01 ;
#         geo:long 4.880009e+00 .
#
#     g2vocab:Assaggi_1015_SC a g2vocab:Toko ;
#         rdfs:label "Assaggi"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         swpo:hasAddress "Tweede Egelantiersdwstr 4-6"^^xsd:string ;
#         swpo:hasZipCode "1015 SC"^^xsd:string ;
#         geo:lat 5.237658e+01 ;
#         geo:long 4.882167e+00 .
#
#     g2vocab:Assagi_1015_SC a g2vocab:Toko ;
#         rdfs:label "Assagi"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120521/9e089194-1f09-4f59-8ca5-7ac7fd76b86f.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         swpo:hasAddress "Tweede Egelantiersdwarsstraat 6"^^xsd:string ;
#         swpo:hasZipCode "1015 SC"^^xsd:string ;
#         geo:lat 5.237682e+01 ;
#         geo:long 4.881959e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Auberge_Jean_&_Marie_1072_CV> a g2vocab:Toko ;
#         rdfs:label "Auberge Jean & Marie"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/2437939b-e64f-4170-8f23-761c03c5731f.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/4d88ba98-fd62-457c-96e5-5c1f4e0200c0.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/5a385fd3-cd93-44f2-91c2-c112227898a7.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/79dfd40a-9de3-4bac-8153-9c4990825ebd.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/99375112-2b4a-4552-b0f0-b351614052a0.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/9e2ac5c4-7638-448e-aa84-9c6e8d0e1942.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/b47fc4cd-57df-43da-a6b8-0c498da05a90.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/be9f766e-97c4-461c-9151-7d1bf8038fd2.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/d9d98f46-c117-424d-ba81-aaac36f2f426.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/ed121e6b-c3b3-4729-918f-e4d2a956e96b.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/64/64df5972-722d-4466-ac9f-a1658f1ac32d/fa683025-1ba1-4aaf-967e-f5549d18b8aa.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.aubergeamsterdam.nl"^^xsd:string ;
#         swpo:hasAddress "Albert Cuypstraat 58-60"^^xsd:string ;
#         swpo:hasZipCode "1072 CV"^^xsd:string ;
#         geo:lat 5.235464e+01 ;
#         geo:long 4.889289e+00 .
#
#     g2vocab:BAK_1013_CR a g2vocab:Toko ;
#         rdfs:label "BAK"^^xsd:string ;
#         g2vocab:use_lat "52.39"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/2d/2d83dc41-a9bb-4320-9ec8-2f5b379ba78e/3dd7fc52-d104-4d6a-8611-03ec71961845.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/2d/2d83dc41-a9bb-4320-9ec8-2f5b379ba78e/3fcb7604-8260-4cdd-9817-accd55195a58.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/2d/2d83dc41-a9bb-4320-9ec8-2f5b379ba78e/5f024637-6fcd-4d7f-90ca-7e6db87a6696.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bakrestaurant.nl/"^^xsd:string ;
#         swpo:hasAddress "Van Diemenkade 410"^^xsd:string ;
#         swpo:hasZipCode "1013 CR"^^xsd:string ;
#         geo:lat 5.239064e+01 ;
#         geo:long 4.886546e+00 .
#
#     g2vocab:BAUT_1093_NJ a g2vocab:Toko ;
#         rdfs:label "BAUT"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.93"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/13/13e47ab4-4b10-4056-9229-18f2f788f33e/22302760-2efe-48c7-8172-bf9c17620f29.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bautamsterdam.nl"^^xsd:string ;
#         swpo:hasAddress "Paradijsplein 1"^^xsd:string ;
#         swpo:hasZipCode "1093 NJ"^^xsd:string ;
#         geo:lat 5.235763e+01 ;
#         geo:long 4.932341e+00 .
#
#     g2vocab:BUFFET_van_Odette_1017_KS a g2vocab:Toko ;
#         rdfs:label "BUFFET van Odette"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20150326/022b4c3d-4149-42cc-9567-6920c541778c.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20150326/2b183bea-9627-4425-94e4-55fb64ec5321.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.buffet-amsterdam.nl/"^^xsd:string ;
#         swpo:hasAddress "Prinsengracht 598"^^xsd:string ;
#         swpo:hasZipCode "1017 KS"^^xsd:string ;
#         geo:lat 5.236234e+01 ;
#         geo:long 4.888987e+00 .
#
#     g2vocab:Back_to_Black_1017_SP a g2vocab:Toko ;
#         rdfs:label "Back to Black"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/18/18e99abe-b20b-4d35-964a-bc51e66bb6dd/15237d7b-bdad-451b-b25e-720d4dca1df1.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/18/18e99abe-b20b-4d35-964a-bc51e66bb6dd/c02922e3-7759-4afa-81f0-96172aaa48c6.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.backtoblackcoffee.nl"^^xsd:string ;
#         swpo:hasAddress "Weteringstraat 48"^^xsd:string ;
#         swpo:hasZipCode "1017 SP"^^xsd:string ;
#         geo:lat 5.236105e+01 ;
#         geo:long 4.888568e+00 .
#
#     g2vocab:Badhuis_Javaplein_1095_CJ a g2vocab:Toko ;
#         rdfs:label "Badhuis Javaplein"^^xsd:string ;
#         g2vocab:opening_hours "Ma-do: 10:00 - 01:00 uur, vr-zo: 10:00 - 03:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.93"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/b7/b7653c34-5a90-461b-84c9-7e44033d6616/8881cef1-7bca-4a53-a4da-f96bc1e10ddc.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://badhuis-javaplein.nl/"^^xsd:string ;
#         swpo:hasAddress "Javaplein 21"^^xsd:string ;
#         swpo:hasZipCode "1095 CJ"^^xsd:string ;
#         geo:lat 5.236353e+01 ;
#         geo:long 4.939925e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Bagels_&_Beans_1072_LM> a g2vocab:Toko ;
#         rdfs:label "Bagels & Beans"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20130501/0eb066c5-fa13-480c-999e-62a745d91aa8.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130501/4e4134d3-449d-48f1-bf29-b24bbb546c96.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130501/a1b68494-b861-470b-8e33-5b9fb328e6e9.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130501/f7ba6f45-3476-47fd-8491-ad7c5a139165.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130501/fc80f5a5-0124-4b30-a45b-514252953fa0.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bagelsbeans.nl/"^^xsd:string,
#             "http://www.facebook.com/BagelsBeansFerdinandBolstraatAmsterdam"^^xsd:string ;
#         swpo:hasAddress "Ferdinand Bolstraat 70"^^xsd:string ;
#         swpo:hasZipCode "1072 LM"^^xsd:string ;
#         geo:lat 5.23553e+01 ;
#         geo:long 4.890385e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Bagels_&_Beans_Amsterdam_Oud_West_1052_ND> a g2vocab:Toko ;
#         rdfs:label "Bagels & Beans Amsterdam Oud West"^^xsd:string ;
#         g2vocab:opening_hours "Ma-vr: 08:30 - 17:30 uur za, zo: 09:00 - 17:30 uur."^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.87"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20130530/12f86ad7-653d-420e-b8d5-a254f50137b2.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130530/683d3909-5646-4b10-a7f8-f9a63c7cfc53.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130530/72c46b7c-70f8-4173-ba8e-5515d3e38c44.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130530/c5f89339-35fa-462b-a39f-fd358f7f9b06.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130530/d2f8caf7-0541-408a-a2b2-6ee7d6c24245.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130530/e236cd0c-6c1c-4769-bb8f-7a7c5e4f953c.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bagelsbeans.nl/nl"^^xsd:string,
#             "http://www.facebook.com/BagelsBeansdeClercqstraatAmsterd"^^xsd:string ;
#         swpo:hasAddress "De Clercqstraat 22HS"^^xsd:string ;
#         swpo:hasZipCode "1052 ND"^^xsd:string ;
#         geo:lat 5.237168e+01 ;
#         geo:long 4.872854e+00 .
#
#     g2vocab:Bajesdorp_1096_AN a g2vocab:Toko ;
#         rdfs:label "Bajesdorp"^^xsd:string ;
#         g2vocab:use_lat "52.33"^^xsd:string ;
#         g2vocab:use_long "4.92"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bajesdorp.nl"^^xsd:string ;
#         swpo:hasAddress "H.J.E. Wenckebachweg 36"^^xsd:string ;
#         swpo:hasZipCode "1096 AN"^^xsd:string ;
#         geo:lat 5.233639e+01 ;
#         geo:long 4.926201e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Bakers_&_Roasters_1072_BH> a g2vocab:Toko ;
#         rdfs:label "Bakers & Roasters"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20140923/3af07551-d0d7-4400-a69b-f54f391eba8a.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bakersandroasters.com"^^xsd:string ;
#         swpo:hasAddress "1e Jacob van Campenstr 54"^^xsd:string ;
#         swpo:hasZipCode "1072 BH"^^xsd:string ;
#         geo:lat 5.235734e+01 ;
#         geo:long 4.889858e+00 .
#
#     g2vocab:Bakhuys_Amsterdam_1018_EX a g2vocab:Toko ;
#         rdfs:label "Bakhuys Amsterdam"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.90"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20150326/0751b8ec-8acd-409e-9264-6aecb0bb050f.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20150326/d938d01a-7014-4a1b-ac0b-7616209a2117.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bakhuys-amsterdam.nl"^^xsd:string ;
#         swpo:hasAddress "Sarphatistraat 61"^^xsd:string ;
#         swpo:hasZipCode "1018 EX"^^xsd:string ;
#         geo:lat 5.23611e+01 ;
#         geo:long 4.906845e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Balthazar's_Keuken_1016_VA> a g2vocab:Toko ;
#         rdfs:label "Balthazar's Keuken"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.87"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120521/8b06c3ad-359a-4f43-8487-8b0e345cfbdb.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         swpo:hasAddress "Elandsgracht 108"^^xsd:string ;
#         swpo:hasZipCode "1016 VA"^^xsd:string ;
#         geo:lat 5.236948e+01 ;
#         geo:long 4.879795e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Bar_&_Restaurant_Puur_Saen_1506_TW> a g2vocab:Toko ;
#         rdfs:label "Bar & Restaurant Puur Saen"^^xsd:string ;
#         g2vocab:use_lat "52.43"^^xsd:string ;
#         g2vocab:use_long "4.81"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20110217/5f981258-3d12-4450-b9e8-280be27b0f1d.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110217/8f0ab417-85cc-44de-bd0d-fec8611d819f.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110217/dc996df2-5f19-4ed2-bdce-903d9e107eb1.jpg"^^xsd:string ;
#         place:in g2vocab:ZAANDAM ;
#         schema:url "http://www.inntelhotelsamsterdamzaandam.nl/nl/Bar-Restaurant-Puur-Saen.html"^^xsd:string ;
#         swpo:hasAddress "Aan de Vaart 1"^^xsd:string ;
#         swpo:hasZipCode "1506 TW"^^xsd:string ;
#         geo:lat 5.243826e+01 ;
#         geo:long 4.815948e+00 .
#
#     g2vocab:Bar_Baarsch_1057_BS a g2vocab:Toko ;
#         rdfs:label "Bar Baarsch"^^xsd:string ;
#         g2vocab:opening_hours "Ma-do: 10:00 - 01:00 uur, vr: 10:00 - 03:00 uur, za: 11:00 - 03:00 uur, zo: 11:00 - 01:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.85"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/28/288f86d1-cec6-4ed1-9542-0a576da76179/265691c0-d058-4444-9731-0c16e6753a97.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://barbaarsch.nl"^^xsd:string ;
#         swpo:hasAddress "Jan Evertsenstraat 91"^^xsd:string ;
#         swpo:hasZipCode "1057 BS"^^xsd:string ;
#         geo:lat 5.237051e+01 ;
#         geo:long 4.853521e+00 .
#
#     g2vocab:Bar_Basquiat_1094_HM a g2vocab:Toko ;
#         rdfs:label "Bar Basquiat"^^xsd:string ;
#         g2vocab:opening_hours "Ma-do: 07:30 - 01:00 uur, vr: 07:30 - 03:00 uur, za: 09:00 - 03:00 uur, zo: 09:00 - 01:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.93"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/a0/a0de771e-69cf-4556-b4b6-8110cd11d1ec/63ee4ccf-81f1-4d4e-bdc1-71145fd26fda.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/a0/a0de771e-69cf-4556-b4b6-8110cd11d1ec/64f52122-d760-4ed2-8e9d-e6248667aff2.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/a0/a0de771e-69cf-4556-b4b6-8110cd11d1ec/7bca23b4-3ab9-4589-aa79-a11403062c18.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.barbasquiat.nl/nl/index.html"^^xsd:string ;
#         swpo:hasAddress "Javastraat 90"^^xsd:string ;
#         swpo:hasZipCode "1094 HM"^^xsd:string ;
#         geo:lat 5.236372e+01 ;
#         geo:long 4.935884e+00 .
#
#     g2vocab:Bar_Brandstof_1016_TD a g2vocab:Toko ;
#         rdfs:label "Bar Brandstof"^^xsd:string ;
#         g2vocab:opening_hours "Ma-zo: 08:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.87"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20150326/ff742210-41aa-4e37-bb3e-a09fc8a56959.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20150326/ff9cf708-5035-4d7d-9db7-da8926c7c9e8.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bar-brandstof.nl"^^xsd:string ;
#         swpo:hasAddress "Marnixstraat 341"^^xsd:string ;
#         swpo:hasZipCode "1016 TD"^^xsd:string ;
#         geo:lat 5.237253e+01 ;
#         geo:long 4.87607e+00 .
#
#     g2vocab:Bar_Brasserie_Occo_1016_GB a g2vocab:Toko ;
#         rdfs:label "Bar Brasserie Occo"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/6f/6fe24583-d855-4138-9e56-df1cefa38039/d5d59b77-a7ad-4f6c-b8e5-a92de2370f31.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "https://www.dylanamsterdam.com/restaurants/brasserie-occo/"^^xsd:string ;
#         swpo:hasAddress "Keizersgracht 384"^^xsd:string ;
#         swpo:hasZipCode "1016 GB"^^xsd:string ;
#         geo:lat 5.236929e+01 ;
#         geo:long 4.884014e+00 .
#
#     g2vocab:Bar_James_1094_HA a g2vocab:Toko ;
#         rdfs:label "Bar James"^^xsd:string ;
#         g2vocab:opening_hours "Ma-do: 09:00 - 01:00 uur, vr, za: 09:00 - 03:00 uur, zo: 09:00 - 01:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.93"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/cd/cdea215e-c7b7-4da5-b8bf-1cb325ceb471/02f70cd6-60b9-4212-b5d3-57986ae5783d.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/cd/cdea215e-c7b7-4da5-b8bf-1cb325ceb471/fc50cc3b-6020-4e76-ab43-21733430c0d5.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "https://www.facebook.com/barjameswoodbury"^^xsd:string ;
#         swpo:hasAddress "Javastraat 49"^^xsd:string ;
#         swpo:hasZipCode "1094 HA"^^xsd:string ;
#         geo:lat 5.236386e+01 ;
#         geo:long 4.933527e+00 .
#
#     g2vocab:Bar_Spek_1057_JT a g2vocab:Toko ;
#         rdfs:label "Bar Spek"^^xsd:string ;
#         g2vocab:opening_hours "Ma-do: 08:00 - 01:00 uur vr, za: 09:00 - 02:00 uur zo: 09:00 - 01:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.86"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20130808/2f4a4145-9f02-4881-b550-f95c8630fe6b.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20130808/9e368255-2083-4f38-9694-2dae85d7f416.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.barspek.nl/"^^xsd:string ;
#         swpo:hasAddress "Admiraal de Ruijterweg 1"^^xsd:string ;
#         swpo:hasZipCode "1057 JT"^^xsd:string ;
#         geo:lat 5.237014e+01 ;
#         geo:long 4.864562e+00 .
#
#     g2vocab:Bar_Waldorf_1016_TV a g2vocab:Toko ;
#         rdfs:label "Bar Waldorf"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         swpo:hasAddress "Elandsgracht 2"^^xsd:string ;
#         swpo:hasZipCode "1016 TV"^^xsd:string ;
#         geo:lat 5.237029e+01 ;
#         geo:long 4.882295e+00 .
#
#     g2vocab:Barra_1073_CL a g2vocab:Toko ;
#         rdfs:label "Barra"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120912/4ee1c2e6-d258-4dd4-8c0a-d60185ad67d6.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         swpo:hasAddress "Eerste Sweelinckstraat 23"^^xsd:string ;
#         swpo:hasZipCode "1073 CL"^^xsd:string ;
#         geo:lat 5.235585e+01 ;
#         geo:long 4.898066e+00 .
#
#     g2vocab:Bazar_Amsterdam_1073_BL a g2vocab:Toko ;
#         rdfs:label "Bazar Amsterdam"^^xsd:string ;
#         g2vocab:opening_hours "ma-do: 11:00 - 00:00 uur vr: 11:00 - 01:00 uur za: 09:00 - 01:00 uur zo: 09:00 - 00:00 uur"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20110131/144d7f39-8e68-4f2d-9227-6285f603d351.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110131/75ef8b18-b618-4b3e-881a-8094a1db466d.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20110131/afd3a322-1cb8-4231-b63a-8cf4fb7afad9.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bazaramsterdam.nl"^^xsd:string,
#             "http://www.facebook.com/bazar.amsterdam.5"^^xsd:string ;
#         swpo:hasAddress "Albert Cuypstraat 182"^^xsd:string ;
#         swpo:hasZipCode "1073 BL"^^xsd:string ;
#         geo:lat 5.235551e+01 ;
#         geo:long 4.893203e+00 .
#
#     g2vocab:Beach_Club_Far_Out_2042_AD a g2vocab:Toko ;
#         rdfs:label "Beach Club Far Out"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.52"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20141107/f5a9f9f0-bf48-4e0b-92f1-39290b77c884.jpg"^^xsd:string ;
#         place:in g2vocab:ZANDVOORT ;
#         schema:url "http://www.beachclubfarout.nl"^^xsd:string ;
#         swpo:hasAddress "Boulevard Paulus Loot 7"^^xsd:string ;
#         swpo:hasZipCode "2042 AD"^^xsd:string ;
#         geo:lat 5.237182e+01 ;
#         geo:long 4.52445e+00 .
#
#     g2vocab:Beach_Inn_1976_GA a g2vocab:Toko ;
#         rdfs:label "Beach Inn"^^xsd:string ;
#         g2vocab:use_lat "52.44"^^xsd:string ;
#         g2vocab:use_long "4.56"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20130329/daceec5e-18af-47b3-a019-78e4cb186ee6.jpg"^^xsd:string ;
#         place:in g2vocab:IJMUIDEN ;
#         schema:url "http://www.beachinn-events.nl/"^^xsd:string,
#             "http://www.facebook.com/paviljoenbeachinn/"^^xsd:string ;
#         swpo:hasAddress "Kennemerstrand 800"^^xsd:string ;
#         swpo:hasZipCode "1976 GA"^^xsd:string ;
#         geo:lat 5.244806e+01 ;
#         geo:long 4.560705e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Beddington's_1017_WE> a g2vocab:Toko ;
#         rdfs:label "Beddington's"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.90"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120521/77be1376-67e9-4511-bc1c-583dfb9c0669.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.beddington.nl"^^xsd:string ;
#         swpo:hasAddress "Utrechtsedwarsstraat 141"^^xsd:string ;
#         swpo:hasZipCode "1017 WE"^^xsd:string ;
#         geo:lat 5.236194e+01 ;
#         geo:long 4.901373e+00 .
#
#     g2vocab:Bedford-Stuyvesant_1094_HA a g2vocab:Toko ;
#         rdfs:label "Bedford-Stuyvesant"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.93"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/17/17ce3292-c2f0-491e-a8e4-dcf5b91624b6/743dceff-e72a-4fc3-ba26-f907a13037e7.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/17/17ce3292-c2f0-491e-a8e4-dcf5b91624b6/93b615aa-919c-4910-a6f7-b1c1e155cb25.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bedfordstuyvesant.nl/"^^xsd:string ;
#         swpo:hasAddress "Javastraat 55"^^xsd:string ;
#         swpo:hasZipCode "1094 HA"^^xsd:string ;
#         geo:lat 5.236384e+01 ;
#         geo:long 4.933756e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Beter_&_Leuk_1091_GW> a g2vocab:Toko ;
#         rdfs:label "Beter & Leuk"^^xsd:string ;
#         g2vocab:opening_hours "Ma-vr: 08:30 - 16:00 uur za, zo: 09:30 - 17:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.91"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20150323/8fbaae17-a1b5-4624-8624-5cb19c9643bf.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20150323/d6d8dd6d-b311-43e6-8929-84c6e1d05b13.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.beterenleuk.nl/"^^xsd:string ;
#         swpo:hasAddress "Eerste Oosterparkstraat 91"^^xsd:string ;
#         swpo:hasZipCode "1091 GW"^^xsd:string ;
#         geo:lat 5.235624e+01 ;
#         geo:long 4.910254e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Betty's_1079_GX> a g2vocab:Toko ;
#         rdfs:label "Betty's"^^xsd:string ;
#         g2vocab:opening_hours "Wo-zo: 17:30 - 23:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.34"^^xsd:string ;
#         g2vocab:use_long "4.90"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bettys.nl/"^^xsd:string ;
#         swpo:hasAddress "Rijnstraat 75"^^xsd:string ;
#         swpo:hasZipCode "1079 GX"^^xsd:string ;
#         geo:lat 5.234558e+01 ;
#         geo:long 4.905764e+00 .
#
#     g2vocab:Betty_Blue_1011_HA a g2vocab:Toko ;
#         rdfs:label "Betty Blue"^^xsd:string ;
#         g2vocab:use_lat "52.37"^^xsd:string ;
#         g2vocab:use_long "4.90"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/61/61c3bb20-16e2-4809-a5a4-d2b5b895d476/af284107-420d-4d44-b8df-3974f9c485b3.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bettyblueamsterdam.nl"^^xsd:string ;
#         swpo:hasAddress "Snoekjessteeg 1-3"^^xsd:string ;
#         swpo:hasZipCode "1011 HA"^^xsd:string ;
#         geo:lat 5.237057e+01 ;
#         geo:long 4.900796e+00 .
#
#     g2vocab:Beulings_1017_BA a g2vocab:Toko ;
#         rdfs:label "Beulings"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.88"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120521/5238dcb8-3bfe-439e-a974-4cc7ec369a64.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.beulings.nl"^^xsd:string ;
#         swpo:hasAddress "Beulingstraat 9"^^xsd:string ;
#         swpo:hasZipCode "1017 BA"^^xsd:string ;
#         geo:lat 5.236802e+01 ;
#         geo:long 4.887692e+00 .
#
#     g2vocab:Bicken_1054_HJ a g2vocab:Toko ;
#         rdfs:label "Bicken"^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.87"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120521/3b24bb08-49d4-461f-906b-b1f14cb8b16a.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bicken.nl"^^xsd:string ;
#         swpo:hasAddress "Overtoom 28-30"^^xsd:string ;
#         swpo:hasZipCode "1054 HJ"^^xsd:string ;
#         geo:lat 5.236382e+01 ;
#         geo:long 4.878564e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Bickers_a/d_Werf_1013_KX> a g2vocab:Toko ;
#         rdfs:label "Bickers a/d Werf"^^xsd:string ;
#         g2vocab:use_lat "52.38"^^xsd:string ;
#         g2vocab:use_long "4.89"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120521/319574ff-d75a-4f1a-ab48-573a7cb24e69.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/20120521/ae21a71a-1373-4572-a9dc-3d715ec17ad5.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bickersaandewerf.nl"^^xsd:string ;
#         swpo:hasAddress "Bickerswerf 2"^^xsd:string ;
#         swpo:hasZipCode "1013 KX"^^xsd:string ;
#         geo:lat 5.238574e+01 ;
#         geo:long 4.890054e+00 .
#
#     <http://data.krw.d2s.labs.vu.nl/group2/resource/Biologische_Snackbar_'t_Wethoudertje_1098_KV> a g2vocab:Toko ;
#         rdfs:label "Biologische Snackbar 't Wethoudertje"^^xsd:string ;
#         g2vocab:use_lat "52.35"^^xsd:string ;
#         g2vocab:use_long "4.93"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/7d/7d37a0bb-6323-4fa4-abd2-865dadec6143/3943938c-a962-4fd1-82ac-aae54cf98405.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/7d/7d37a0bb-6323-4fa4-abd2-865dadec6143/8fb89606-72b3-4c69-b9d0-d25f0e7b1192.jpg"^^xsd:string,
#             "https://media.iamsterdam.com/ndtrc/Images/7d/7d37a0bb-6323-4fa4-abd2-865dadec6143/9f6de73a-b072-49d8-8ad0-b653a8987fe5.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.wethoudertje.nl"^^xsd:string ;
#         swpo:hasAddress "Wethouder Frankeweg 11"^^xsd:string ;
#         swpo:hasZipCode "1098 KV"^^xsd:string ;
#         geo:lat 5.235135e+01 ;
#         geo:long 4.93594e+00 .
#
#     g2vocab:Bistro_Baret_1018_XS a g2vocab:Toko ;
#         rdfs:label "Bistro Baret"^^xsd:string ;
#         g2vocab:opening_hours "Ma-zo: 16:00 - 22:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.36"^^xsd:string ;
#         g2vocab:use_long "4.90"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/6e/6e208311-92b2-452e-9e4f-36d2b2cf4c28/69e83e89-073a-457d-81a8-9f109bebadaf.jpg"^^xsd:string ;
#         place:in g2vocab:AMSTERDAM ;
#         schema:url "http://www.bistrobaret.nl/"^^xsd:string ;
#         swpo:hasAddress "Korte Amstelstraat 18"^^xsd:string ;
#         swpo:hasZipCode "1018 XS"^^xsd:string ;
#         geo:lat 5.236167e+01 ;
#         geo:long 4.904828e+00 .
#
#     g2vocab:Bistro_Belle_3611_AE a g2vocab:Toko ;
#         rdfs:label "Bistro Belle"^^xsd:string ;
#         g2vocab:opening_hours "Ma-zo: 12:00 - 22:00 uur."^^xsd:string ;
#         g2vocab:use_lat "52.12"^^xsd:string ;
#         g2vocab:use_long "5.07"^^xsd:string ;
#         dbpedia-owl:Media "https://media.iamsterdam.com/ndtrc/Images/20120305/4c0876b9-c116-43e8-9045-e203cddf66f7.jpg"^^xsd:string ;
#         place:in g2vocab:OUD_ZUILEN ;
#         schema:url "http://www.bistrobelle.nl/"^^xsd:string ;
#         swpo:hasAddress "Dorpsstraat 12"^^xsd:string ;
#         swpo:hasZipCode "3611 AE"^^xsd:string ;
#         geo:lat 5.212711e+01 ;
#         geo:long 5.07079e+00 .
#
# ...
#         g2vocab:Destination "Haarlem Station"^^xsd:string,
#             "Station Zuid Amsterdam"^^xsd:string .
#
#     g2vocab:ROUTE_241 a g2vocab:Route ;
#         g2vocab:Destination "Amstelveen via KLM Hoofdkantoor"^^xsd:string,
#             "Amsterdam via KLM Hoofdkantoor"^^xsd:string .
#
#     g2vocab:ROUTE_280 a g2vocab:Route ;
#         g2vocab:Destination "IJmuiden Zeewijk N"^^xsd:string,
#             "IJmuiden via Haarlem NS"^^xsd:string .
#
#     g2vocab:ROUTE_371 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam West"^^xsd:string,
#             "Purmerend De Purmer"^^xsd:string .
#
#     g2vocab:ROUTE_372 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam West"^^xsd:string,
#             "Purmerend Overwhere"^^xsd:string .
#
#     g2vocab:ROUTE_374 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam West"^^xsd:string,
#             "Purmerend Overwhere"^^xsd:string .
#
#     g2vocab:ROUTE_612 a g2vocab:Route ;
#         g2vocab:Destination "Abcoude Viadukt A2"^^xsd:string,
#             "Amstelveen Uilenstede"^^xsd:string .
#
#     g2vocab:ROUTE_197 a g2vocab:Route ;
#         g2vocab:Destination "Leidseplein via Airport/Plaza"^^xsd:string,
#             "Schiphol P30 via Airport/Plaza"^^xsd:string .
#
#     g2vocab:ROUTE_199 a g2vocab:Route ;
#         g2vocab:Destination "Schiphol P30 via Airport/Plaza"^^xsd:string,
#             "Station Zuid Amsterdam"^^xsd:string .
#
#     g2vocab:ROUTE_373 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam West"^^xsd:string,
#             "Edam-Volendam"^^xsd:string .
#
#     g2vocab:ROUTE_375 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam ZO"^^xsd:string,
#             "Purmerend Overwhere"^^xsd:string .
#
#     g2vocab:ROUTE_376 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam ZO"^^xsd:string,
#             "Purmerend Overwhere"^^xsd:string .
#
#     g2vocab:ROUTE_377 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam ZO"^^xsd:string,
#             "Purmerend De Purmer"^^xsd:string .
#
#     g2vocab:ROUTE_378 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam ZO"^^xsd:string,
#             "Edam-Volendam"^^xsd:string .
#
#     g2vocab:ROUTE_379 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam ZO"^^xsd:string,
#             "Hoorn Station"^^xsd:string .
#
#     g2vocab:ROUTE_N92 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam via Amsterdam Centraal Station"^^xsd:string,
#             "Zaandam Ged. Gracht"^^xsd:string,
#             "Zaandam Station"^^xsd:string .
#
#     g2vocab:ZAANDAM a dbpedia-owl:city ;
#         rdfs:label "ZAANDAM"@nl .
#
#     g2vocab:ROUTE_142 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Marnixstraat"^^xsd:string,
#             "Wilnis via Amstelveen"^^xsd:string .
#
#     g2vocab:ROUTE_242 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Station Zuid"^^xsd:string,
#             "Wilnis"^^xsd:string .
#
#     g2vocab:ROUTE_275 a g2vocab:Route ;
#         g2vocab:Destination "Aalsmeer via Amstelveen"^^xsd:string .
#
#     g2vocab:ROUTE_392 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam CS IJzijde"^^xsd:string,
#             "Zaandam Station"^^xsd:string .
#
#     g2vocab:ROUTE_195 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Station Lelylaan"^^xsd:string,
#             "Lelylaan NS Amsterdam"^^xsd:string,
#             "Lelylaan NS via Airport/Plaza"^^xsd:string,
#             "Schiphol P30 via Airp./Plaza"^^xsd:string .
#
#     g2vocab:ROUTE_611 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Noord"^^xsd:string,
#             "Monickendam"^^xsd:string,
#             "Monnickendam"^^xsd:string .
#
#     g2vocab:ROUTE_105 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Noord naar purmerend"^^xsd:string,
#             "Purmerend"^^xsd:string .
#
#     g2vocab:ROUTE_240 a g2vocab:Route ;
#         g2vocab:Destination "Amstelstation"^^xsd:string,
#             "Science Park A`dam"^^xsd:string .
#
#     g2vocab:ROUTE_300 a g2vocab:Route ;
#         g2vocab:Destination "Amstelveen Busstation"^^xsd:string,
#             "Bijlmer ArenA via Schiphol Airport/Plaza"^^xsd:string,
#             "Haarlem Station"^^xsd:string,
#             "Haarlem via Schiphol Airport/Plaza"^^xsd:string,
#             "Schiphol Airport/Plaza"^^xsd:string .
#
#     g2vocab:ROUTE_391 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam CS IJzijde"^^xsd:string,
#             "Zaandam Schipbeek"^^xsd:string,
#             "Zaandam Zaanse Schans"^^xsd:string .
#
#     g2vocab:ROUTE_394 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam CS IJzijde"^^xsd:string,
#             "Zaandam Station"^^xsd:string .
#
#     g2vocab:ZANDVOORT a dbpedia-owl:city ;
#         rdfs:label "ZANDVOORT"@nl .
#
#     g2vocab:ROUTE_120 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Station Bijlmer"^^xsd:string,
#             "Breukelen"^^xsd:string,
#             "Loenen ad Vecht"^^xsd:string,
#             "Utrecht Centraal"^^xsd:string .
#
#     g2vocab:ROUTE_126 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Station Bijlmer"^^xsd:string,
#             "Mijdrecht"^^xsd:string,
#             "Vinkeveen"^^xsd:string .
#
#     g2vocab:ROUTE_26 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "IJburg"^^xsd:string .
#
#     g2vocab:ROUTE_192 a g2vocab:Route ;
#         g2vocab:Destination "Osdorpplein Amsterdam"^^xsd:string,
#             "Schiphol P30 via Airport/Plaza"^^xsd:string .
#
#     g2vocab:ROUTE_31 a g2vocab:Route ;
#         g2vocab:Destination "Buikslotermeerplein"^^xsd:string,
#             "Zunderdorp"^^xsd:string .
#
#     g2vocab:ROUTE_N70 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam CS via Amstelveen"^^xsd:string,
#             "Uithoorn Amstelplein"^^xsd:string,
#             "Wilnis"^^xsd:string .
#
#     g2vocab:ROUTE_125 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam CS"^^xsd:string,
#             "Landsmeer"^^xsd:string,
#             "Purmerend 392 Zaandam Station"^^xsd:string .
#
#     g2vocab:ROUTE_231 a g2vocab:Route ;
#         g2vocab:Destination "Abberdaan"^^xsd:string,
#             "Station Sloterdijk"^^xsd:string .
#
#     g2vocab:ROUTE_247 a g2vocab:Route ;
#         g2vocab:Destination "Schiphol Zuid"^^xsd:string .
#
#     g2vocab:ROUTE_49 a g2vocab:Route ;
#         g2vocab:Destination "Station Bijlmer ArenA"^^xsd:string .
#
#     g2vocab:ROUTE_398 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Riekerpolder (R-Net)"^^xsd:string,
#             "Amsterdam Slotervaart"^^xsd:string,
#             "Zaandam medisch centrum"^^xsd:string,
#             "Zaandam zaans medisch centrum"^^xsd:string .
#
#     g2vocab:ROUTE_66 a g2vocab:Route ;
#         g2vocab:Destination "IJburg"^^xsd:string,
#             "Station Bijlmer ArenA"^^xsd:string .
#
#     g2vocab:ROUTE_80 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Marnixstraat"^^xsd:string,
#             "Haarlem Centrum Tempeliersstr."^^xsd:string,
#             "Zandvoort Busstation"^^xsd:string .
#
#     g2vocab:ROUTE_32 a g2vocab:Route ;
#         g2vocab:Destination "Buikslotermeerplein"^^xsd:string,
#             "centraal station"^^xsd:string .
#
#     g2vocab:ROUTE_51 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Westwijk"^^xsd:string .
#
#     g2vocab:ROUTE_53 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Gaasperplas"^^xsd:string .
#
#     g2vocab:ROUTE_40 a g2vocab:Route ;
#         g2vocab:Destination "Amstelstation"^^xsd:string,
#             "Muiderpoortstation"^^xsd:string .
#
#     g2vocab:ROUTE_249 a g2vocab:Route ;
#         g2vocab:Destination "Weesp"^^xsd:string .
#
#     g2vocab:ROUTE_33 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Nieuwendam"^^xsd:string .
#
#     g2vocab:ROUTE_54 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Gein"^^xsd:string .
#
#     g2vocab:ROUTE_15 a g2vocab:Route ;
#         g2vocab:Destination "Station Sloterdijk"^^xsd:string .
#
#     g2vocab:ROUTE_64 a g2vocab:Route ;
#         g2vocab:Destination "Station Lelylaan"^^xsd:string,
#             "Station Sloterdijk"^^xsd:string .
#
#     g2vocab:ROUTE_9 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Diemen (Sniep)"^^xsd:string .
#
#     g2vocab:ROUTE_34 a g2vocab:Route ;
#         g2vocab:Destination "Buikslotermeerplein"^^xsd:string,
#             "Centraal Station"^^xsd:string .
#
#     g2vocab:ROUTE_82 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Marnixstraat"^^xsd:string,
#             "Amsterdam Station Sloterdijk uitstap"^^xsd:string,
#             "IJmuiden Zeewijk"^^xsd:string,
#             "IJmuiden aan Zee"^^xsd:string,
#             "Velsen Zuid De Wijde Blik"^^xsd:string .
#
#     g2vocab:ROUTE_174 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam CS via Amstelveen"^^xsd:string,
#             "Uithoorn via Amstelveen"^^xsd:string,
#             "Wilnis via Amstelveen"^^xsd:string .
#
#     g2vocab:ROUTE_4 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Station RAI"^^xsd:string .
#
#     g2vocab:ROUTE_45 a g2vocab:Route ;
#         g2vocab:Destination "Station Bijlmer ArenA"^^xsd:string,
#             "Station Holendrecht"^^xsd:string .
#
#     g2vocab:ROUTE_245 a g2vocab:Route ;
#         g2vocab:Destination "Schiphol Zuid"^^xsd:string .
#
#     g2vocab:ROUTE_63 a g2vocab:Route ;
#         g2vocab:Destination "Osdorp De Aker"^^xsd:string,
#             "Station Lelylaan"^^xsd:string .
#
#     g2vocab:ROUTE_13 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Geuzenveld"^^xsd:string .
#
#     g2vocab:ROUTE_16 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "VU medisch centrum"^^xsd:string .
#
#     g2vocab:ROUTE_35 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Molenwijk"^^xsd:string .
#
#     g2vocab:ROUTE_5 a g2vocab:Route ;
#         g2vocab:Destination "A`veen Binnenhof"^^xsd:string,
#             "Centraal Station"^^xsd:string .
#
#     g2vocab:ROUTE_24 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "VU medisch centrum"^^xsd:string .
#
#     g2vocab:ROUTE_50 a g2vocab:Route ;
#         g2vocab:Destination "Gein"^^xsd:string,
#             "Isolatorweg"^^xsd:string .
#
#     g2vocab:ROUTE_170 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam CS via Amstelveen"^^xsd:string,
#             "Uithoorn via Amstelveen"^^xsd:string .
#
#     g2vocab:ROUTE_172 a g2vocab:Route ;
#         g2vocab:Destination "Aalsmeer via Amstelveen"^^xsd:string,
#             "Amsterdam CS via Amstelveen"^^xsd:string,
#             "Kudelstaart via Amstelveen"^^xsd:string .
#
#     g2vocab:ROUTE_22 a g2vocab:Route ;
#         g2vocab:Destination "Houthaven"^^xsd:string,
#             "Indische Buurt"^^xsd:string,
#             "Spaarndammerbuurt"^^xsd:string .
#
#     g2vocab:ROUTE_2 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Nieuw Sloten"^^xsd:string .
#
#     g2vocab:ROUTE_361 a g2vocab:Route ;
#         g2vocab:Destination "Banne Buiksloot"^^xsd:string,
#             "Centraal Station"^^xsd:string .
#
#     g2vocab:ROUTE_145 a g2vocab:Route ;
#         g2vocab:Destination "Amsterdam Marnixstraat"^^xsd:string,
#             "Hoofddorp via Badhoevedorp"^^xsd:string,
#             "Leidseplein via Badhoevedorp"^^xsd:string .
#
#     g2vocab:ROUTE_17 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Osdorp Dijkgraafplein"^^xsd:string .
#
#     g2vocab:ROUTE_12 a g2vocab:Route ;
#         g2vocab:Destination "Amstelstation"^^xsd:string,
#             "Station Sloterdijk"^^xsd:string .
#
#     g2vocab:ROUTE_3 a g2vocab:Route ;
#         g2vocab:Destination "Muiderpoortstation"^^xsd:string,
#             "Zoutkeetsgracht"^^xsd:string .
#
#     g2vocab:ROUTE_348 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Stat.Sloterdijk"^^xsd:string,
#             "station Sloterdijk"^^xsd:string .
#
#     g2vocab:ROUTE_10 a g2vocab:Route ;
#         g2vocab:Destination "Azartplein"^^xsd:string,
#             "Tropenmuseum"^^xsd:string,
#             "Westergasfabriek"^^xsd:string .
#
#     g2vocab:ROUTE_1 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Osdorp De Aker"^^xsd:string .
#
#     g2vocab:ROUTE_36 a g2vocab:Route ;
#         g2vocab:Destination "Banne Buiksloot"^^xsd:string,
#             "Station Sloterdijk"^^xsd:string .
#
#     g2vocab:ROUTE_369 a g2vocab:Route ;
#         g2vocab:Destination "Schiphol Plaza"^^xsd:string,
#             "Stat.Sloterdijk"^^xsd:string .
#
#     g2vocab:ROUTE_48 a g2vocab:Route ;
#         g2vocab:Destination "Borneo Eiland"^^xsd:string,
#             "Station Sloterdijk 48 en 348 tijdelijk buiten gebruik (zie foto). 36 Banne Buiksloot rijdt wel."^^xsd:string .
#
#     g2vocab:ROUTE_18 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Slotervaart"^^xsd:string .
#
#     g2vocab:ROUTE_363 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Molenwijk"^^xsd:string .
#
#     g2vocab:ROUTE_41 a g2vocab:Route ;
#         g2vocab:Destination "Gaasperplas"^^xsd:string,
#             "Muiderpoortstation"^^xsd:string .
#
#     g2vocab:ROUTE_47 a g2vocab:Route ;
#         g2vocab:Destination "Station 47 Station Bijlmer ArenA"^^xsd:string,
#             "Station Bijlmer ArenA"^^xsd:string,
#             "Station Holendrecht"^^xsd:string .
#
#     g2vocab:ROUTE_69 a g2vocab:Route ;
#         g2vocab:Destination "Schiphol Plaza"^^xsd:string,
#             "Station Sloterdijk"^^xsd:string .
#
#     g2vocab:ROUTE_352 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station N"^^xsd:string,
#             "Geuzenveld"^^xsd:string .
#
#     g2vocab:ROUTE_359 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Ijburg"^^xsd:string .
#
#     g2vocab:ROUTE_38 a g2vocab:Route ;
#         g2vocab:Destination "Elzenhagen Noord"^^xsd:string,
#             "Molenwijk"^^xsd:string,
#             "Nieuwendam Amerbos"^^xsd:string .
#
#     g2vocab:ROUTE_354 a g2vocab:Route ;
#         g2vocab:Destination "A`veen Waardhuizen"^^xsd:string,
#             "Centraal Station"^^xsd:string .
#
#     g2vocab:ROUTE_61 a g2vocab:Route ;
#         g2vocab:Destination "Slotervaart"^^xsd:string,
#             "Station Sloterdijk"^^xsd:string .
#
#     g2vocab:ROUTE_65 a g2vocab:Route ;
#         g2vocab:Destination "KNSM Eiland"^^xsd:string,
#             "Station Zuid"^^xsd:string .
#
#     g2vocab:ROUTE_230 a g2vocab:Route ;
#         g2vocab:Destination "Buikslotermeerplein"^^xsd:string,
#             "Ransdorp"^^xsd:string .
#
#     g2vocab:ROUTE_21 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Geuzenveld"^^xsd:string .
#
#     g2vocab:ROUTE_357 a g2vocab:Route ;
#         g2vocab:Destination "Bijlmermeer"^^xsd:string,
#             "Centraal Station"^^xsd:string .
#
#     g2vocab:ROUTE_62 a g2vocab:Route ;
#         g2vocab:Destination "Amstelstation"^^xsd:string,
#             "Station Lelylaan"^^xsd:string .
#
#     g2vocab:ROUTE_14 a g2vocab:Route ;
#         g2vocab:Destination "Flevopark"^^xsd:string,
#             "Slotermeer"^^xsd:string .
#
#     g2vocab:ROUTE_30 a g2vocab:Route ;
#         g2vocab:Destination "Buikslotermeerplein"^^xsd:string,
#             "Holysloot"^^xsd:string .
#
#     g2vocab:ROUTE_358 a g2vocab:Route ;
#         g2vocab:Destination "Badhoevedorp N"^^xsd:string,
#             "Centraal Station N"^^xsd:string .
#
#     g2vocab:ROUTE_7 a g2vocab:Route ;
#         g2vocab:Destination "Flevopark"^^xsd:string,
#             "Slotermeer"^^xsd:string .
#
#     g2vocab:ROUTE_355 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Gein"^^xsd:string .
#
#     g2vocab:ROUTE_353 a g2vocab:Route ;
#         g2vocab:Destination "Centraal Station"^^xsd:string,
#             "Osdorp de Aker"^^xsd:string .
#
#     g2vocab:ROUTE_37 a g2vocab:Route ;
#         g2vocab:Destination "Amstelstation"^^xsd:string,
#             "Molenwijk"^^xsd:string .
#
#     g2vocab:AMSTERDAM a dbpedia-owl:city ;
#         rdfs:label "AMSTERDAM"@nl .
# }

# %% [markdown]
# ## Graph handling

# %%
# Saving the RDF to a file
with open('extended-going-out-stops_13-4_v2.ttl','w') as f:
    graph.serialize(f, format='turtle')

# %%
#CLEARING THE DATASET

# Clear the graph from the dataset (because we're going to start anew)
dataset.remove_graph(graph)
# And get a new object (with the same URI, to create some confusion)
graph = dataset.graph(graph_uri)
